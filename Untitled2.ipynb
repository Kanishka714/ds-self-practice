# %%
import pandas as pd
from apyori import apriori

# %%
movie_data = pd.read_csv("movie_dataset.csv")

# %%
movie_data.head()
# Out:
#     The Revenant 13 Hours              Allied                   Zootopia  \
# 0         Beirut  Martian             Get Out                        NaN
# 1       Deadpool      NaN                 NaN                        NaN
# 2          X-Men   Allied                 NaN                        NaN
# 3  Ninja Turtles    Moana  Ghost in the Shell  Ralph Breaks the Internet
# 4        Mad Max      NaN                 NaN                        NaN
#
#       Jigsaw Achorman Grinch Fast and Furious Ghostbusters Wolverine Mad Max  \
# 0        NaN      NaN    NaN              NaN          NaN       NaN     NaN
# 1        NaN      NaN    NaN              NaN          NaN       NaN     NaN
# 2        NaN      NaN    NaN              NaN          NaN       NaN     NaN
# 3  John Wick      NaN    NaN              NaN          NaN       NaN     NaN
# 4        NaN      NaN    NaN              NaN          NaN       NaN     NaN
#
#   John Wick La La Land The Good Dunosaur Ninja Turtles  \
# 0       NaN        NaN               NaN           NaN
# 1       NaN        NaN               NaN           NaN
# 2       NaN        NaN               NaN           NaN
# 3       NaN        NaN               NaN           NaN
# 4       NaN        NaN               NaN           NaN
#
#   The Good Dunosaur Bad Moms 2 Guns Inside Out Valerian  Spiderman 3
# 0                        NaN    NaN        NaN      NaN          NaN
# 1                        NaN    NaN        NaN      NaN          NaN
# 2                        NaN    NaN        NaN      NaN          NaN
# 3                        NaN    NaN        NaN      NaN          NaN
# 4                        NaN    NaN        NaN      NaN          NaN

# %%
movie_data.shape
# Out:
# (7500, 20)

# %%
records = []

# %%
for i in range(1, 7500):
    records.append([str(movie_data.values[i, j]) for j in range(0, 20)])

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2,min_lift=3, min_length=2)

# %%
association_results = list(association_rules)

# %%
association_results
# Out:
# [RelationRecord(items=frozenset({'13 Hours', 'Beirut'}), support=0.005515485787017395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13 Hours'}), items_add=frozenset({'Beirut'}), confidence=0.26896551724137935, lift=3.1229148972311878)]),
#  RelationRecord(items=frozenset({'Green Lantern', 'Red Sparrow'}), support=0.005798331211992646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Red Sparrow'}), items_add=frozenset({'Green Lantern'}), confidence=0.3037037037037037, lift=3.8279659338482865)]),
#  RelationRecord(items=frozenset({'Green Lantern', 'Star Wars'}), support=0.005232640362042144, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars'}), items_add=frozenset({'Green Lantern'}), confidence=0.37373737373737376, lift=4.710689785556095)]),
#  RelationRecord(items=frozenset({'Star Trek', 'Intern'}), support=0.005515485787017395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Trek'}), items_add=frozenset({'Intern'}), confidence=0.29545454545454547, lift=3.1042482777252465)]),
#  RelationRecord(items=frozenset({'Jumanji', 'Kung Fu Panda'}), support=0.01583934379861406, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kung Fu Panda'}), items_add=frozenset({'Jumanji'}), confidence=0.3246376811594203, lift=3.283995770355166)]),
#  RelationRecord(items=frozenset({'Wonder Woman', 'Jumanji'}), support=0.00537406307452977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'Jumanji'}), confidence=0.37623762376237624, lift=3.8059745888751966)]),
#  RelationRecord(items=frozenset({'The Spy Who Dumped Me', 'Spiderman 3'}), support=0.007636826474331778, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Spy Who Dumped Me'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2621359223300971, lift=3.9861572189163796)]),
#  RelationRecord(items=frozenset({'nan', '13 Hours', 'Beirut'}), support=0.005515485787017395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13 Hours'}), items_add=frozenset({'nan', 'Beirut'}), confidence=0.26896551724137935, lift=3.1229148972311878), OrderedStatistic(items_base=frozenset({'nan', '13 Hours'}), items_add=frozenset({'Beirut'}), confidence=0.26896551724137935, lift=3.1229148972311878)]),
#  RelationRecord(items=frozenset({'The Revenant', 'Coco', 'Intern'}), support=0.005515485787017395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco', 'Intern'}), items_add=frozenset({'The Revenant'}), confidence=0.2378048780487805, lift=3.2970946915351504), OrderedStatistic(items_base=frozenset({'Coco', 'The Revenant'}), items_add=frozenset({'Intern'}), confidence=0.30708661417322836, lift=3.2264627768482876)]),
#  RelationRecord(items=frozenset({'Jumanji', 'Tomb Rider', 'Fantastic Beast'}), support=0.005091217649554518, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Fantastic Beast'}), items_add=frozenset({'Tomb Rider'}), confidence=0.5806451612903225, lift=3.2845935483870963), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Fantastic Beast'}), items_add=frozenset({'Jumanji'}), confidence=0.3157894736842105, lift=3.1944883668398463)]),
#  RelationRecord(items=frozenset({'nan', 'Green Lantern', 'Red Sparrow'}), support=0.005798331211992646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Red Sparrow'}), items_add=frozenset({'nan', 'Green Lantern'}), confidence=0.3037037037037037, lift=3.8279659338482865), OrderedStatistic(items_base=frozenset({'nan', 'Red Sparrow'}), items_add=frozenset({'Green Lantern'}), confidence=0.3037037037037037, lift=3.8279659338482865)]),
#  RelationRecord(items=frozenset({'nan', 'Green Lantern', 'Star Wars'}), support=0.005232640362042144, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars'}), items_add=frozenset({'nan', 'Green Lantern'}), confidence=0.37373737373737376, lift=4.710689785556095), OrderedStatistic(items_base=frozenset({'nan', 'Star Wars'}), items_add=frozenset({'Green Lantern'}), confidence=0.37373737373737376, lift=4.710689785556095)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'Jumanji', 'Intern'}), support=0.008909630886720407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'Jumanji'}), confidence=0.3118811881188119, lift=3.1549526197254916)]),
#  RelationRecord(items=frozenset({'Spiderman 3', 'Moana', 'Intern'}), support=0.004949794937066893, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Moana', 'Intern'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2095808383233533, lift=3.1869808769557664), OrderedStatistic(items_base=frozenset({'Spiderman 3', 'Intern'}), items_add=frozenset({'Moana'}), confidence=0.42168674698795183, lift=3.262305238459308), OrderedStatistic(items_base=frozenset({'Moana', 'Spiderman 3'}), items_add=frozenset({'Intern'}), confidence=0.2892561983471074, lift=3.0391241879827584)]),
#  RelationRecord(items=frozenset({'The Revenant', 'Ninja Turtles', 'Intern'}), support=0.007495403761844152, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ninja Turtles', 'The Revenant'}), items_add=frozenset({'Intern'}), confidence=0.31360946745562135, lift=3.29499635123135)]),
#  RelationRecord(items=frozenset({'Spiderman 3', 'Tomb Rider', 'Intern'}), support=0.0060811766369678975, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2128712871287129, lift=3.237016927499202)]),
#  RelationRecord(items=frozenset({'Star Trek', 'nan', 'Intern'}), support=0.005515485787017395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Trek'}), items_add=frozenset({'nan', 'Intern'}), confidence=0.29545454545454547, lift=3.1042482777252465), OrderedStatistic(items_base=frozenset({'Star Trek', 'nan'}), items_add=frozenset({'Intern'}), confidence=0.29545454545454547, lift=3.1042482777252465)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'The Revenant', 'Intern'}), support=0.006222599349455522, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'The Revenant'}), confidence=0.21782178217821782, lift=3.0200349446709374)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'World War Z', 'Intern'}), support=0.0067882901994060245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'World War Z'}), confidence=0.2376237623762376, lift=3.478752844228522), OrderedStatistic(items_base=frozenset({'World War Z', 'Tomb Rider'}), items_add=frozenset({'Intern'}), confidence=0.32432432432432434, lift=3.407573993012329)]),
#  RelationRecord(items=frozenset({'Iron Man', 'Jumanji', 'Tomb Rider'}), support=0.00537406307452977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Iron Man', 'Tomb Rider'}), items_add=frozenset({'Jumanji'}), confidence=0.3247863247863248, lift=3.285499431422178)]),
#  RelationRecord(items=frozenset({'Jumanji', 'Kung Fu Panda', 'Ninja Turtles'}), support=0.00692971291189365, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kung Fu Panda', 'Ninja Turtles'}), items_add=frozenset({'Jumanji'}), confidence=0.40163934426229514, lift=4.062935340885105)]),
#  RelationRecord(items=frozenset({'Jumanji', 'Kung Fu Panda', 'Tomb Rider'}), support=0.006222599349455522, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kung Fu Panda', 'Tomb Rider'}), items_add=frozenset({'Jumanji'}), confidence=0.3893805309734513, lift=3.9389266588172736)]),
#  RelationRecord(items=frozenset({'nan', 'Jumanji', 'Kung Fu Panda'}), support=0.01583934379861406, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kung Fu Panda'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.3246376811594203, lift=3.283995770355166), OrderedStatistic(items_base=frozenset({'nan', 'Kung Fu Panda'}), items_add=frozenset({'Jumanji'}), confidence=0.3246376811594203, lift=3.283995770355166)]),
#  RelationRecord(items=frozenset({'Jumanji', 'Moana', 'Spiderman 3'}), support=0.004949794937066893, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Moana'}), items_add=frozenset({'Spiderman 3'}), confidence=0.22292993630573252, lift=3.3899732895007197)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'Jumanji', 'The Revenant'}), support=0.006364022061943148, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'The Revenant'}), items_add=frozenset({'Tomb Rider'}), confidence=0.5487804878048781, lift=3.104341463414634)]),
#  RelationRecord(items=frozenset({'Wonder Woman', 'Jumanji', 'nan'}), support=0.00537406307452977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Wonder Woman'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.37623762376237624, lift=3.8059745888751966), OrderedStatistic(items_base=frozenset({'Wonder Woman', 'nan'}), items_add=frozenset({'Jumanji'}), confidence=0.37623762376237624, lift=3.8059745888751966)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'Moana', 'Spiderman 3'}), support=0.0073539810493565266, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Moana', 'Tomb Rider'}), items_add=frozenset({'Spiderman 3'}), confidence=0.20233463035019456, lift=3.0767917660348942)]),
#  RelationRecord(items=frozenset({'Thor', 'Ninja Turtles', 'Spiderman 3'}), support=0.005232640362042144, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ninja Turtles', 'Thor'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2215568862275449, lift=3.369094069924667)]),
#  RelationRecord(items=frozenset({'Spotlight', 'Tomb Rider', 'Spiderman 3'}), support=0.00537406307452977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Spotlight'}), items_add=frozenset({'Spiderman 3'}), confidence=0.20994475138121546, lift=3.192514703261451)]),
#  RelationRecord(items=frozenset({'The Spy Who Dumped Me', 'Spiderman 3', 'nan'}), support=0.007636826474331778, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Spy Who Dumped Me'}), items_add=frozenset({'nan', 'Spiderman 3'}), confidence=0.2621359223300971, lift=3.9861572189163796), OrderedStatistic(items_base=frozenset({'The Spy Who Dumped Me', 'nan'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2621359223300971, lift=3.9861572189163796)]),
#  RelationRecord(items=frozenset({'nan', 'The Revenant', 'Coco', 'Intern'}), support=0.005515485787017395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coco', 'Intern'}), items_add=frozenset({'nan', 'The Revenant'}), confidence=0.2378048780487805, lift=3.2970946915351504), OrderedStatistic(items_base=frozenset({'Coco', 'The Revenant'}), items_add=frozenset({'nan', 'Intern'}), confidence=0.30708661417322836, lift=3.2264627768482876), OrderedStatistic(items_base=frozenset({'nan', 'Coco', 'Intern'}), items_add=frozenset({'The Revenant'}), confidence=0.2378048780487805, lift=3.2970946915351504), OrderedStatistic(items_base=frozenset({'nan', 'Coco', 'The Revenant'}), items_add=frozenset({'Intern'}), confidence=0.30708661417322836, lift=3.2264627768482876)]),
#  RelationRecord(items=frozenset({'nan', 'Jumanji', 'Tomb Rider', 'Fantastic Beast'}), support=0.005091217649554518, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Fantastic Beast'}), items_add=frozenset({'nan', 'Tomb Rider'}), confidence=0.5806451612903225, lift=3.2845935483870963), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Fantastic Beast'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.3157894736842105, lift=3.1944883668398463), OrderedStatistic(items_base=frozenset({'nan', 'Jumanji', 'Fantastic Beast'}), items_add=frozenset({'Tomb Rider'}), confidence=0.5806451612903225, lift=3.2845935483870963), OrderedStatistic(items_base=frozenset({'nan', 'Tomb Rider', 'Fantastic Beast'}), items_add=frozenset({'Jumanji'}), confidence=0.3157894736842105, lift=3.1944883668398463)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'Jumanji', 'Ninja Turtles', 'Intern'}), support=0.004525526799604016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Intern'}), items_add=frozenset({'Ninja Turtles', 'Tomb Rider'}), confidence=0.26016260162601623, lift=4.258355916892501), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Ninja Turtles', 'Intern'}), items_add=frozenset({'Jumanji'}), confidence=0.36781609195402293, lift=3.720783385131468)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'nan', 'Jumanji', 'Intern'}), support=0.008909630886720407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.3118811881188119, lift=3.1549526197254916), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'nan', 'Intern'}), items_add=frozenset({'Jumanji'}), confidence=0.3118811881188119, lift=3.1549526197254916)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'Ninja Turtles', 'Moana', 'Intern'}), support=0.004666949512091642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ninja Turtles', 'Moana', 'Tomb Rider'}), items_add=frozenset({'Intern'}), confidence=0.2869565217391304, lift=3.0149622068609077)]),
#  RelationRecord(items=frozenset({'Spiderman 3', 'nan', 'Moana', 'Intern'}), support=0.004949794937066893, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Moana', 'Intern'}), items_add=frozenset({'nan', 'Spiderman 3'}), confidence=0.2095808383233533, lift=3.1869808769557664), OrderedStatistic(items_base=frozenset({'Spiderman 3', 'Intern'}), items_add=frozenset({'nan', 'Moana'}), confidence=0.42168674698795183, lift=3.262305238459308), OrderedStatistic(items_base=frozenset({'Moana', 'Spiderman 3'}), items_add=frozenset({'nan', 'Intern'}), confidence=0.2892561983471074, lift=3.0391241879827584), OrderedStatistic(items_base=frozenset({'nan', 'Moana', 'Intern'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2095808383233533, lift=3.1869808769557664), OrderedStatistic(items_base=frozenset({'Spiderman 3', 'nan', 'Intern'}), items_add=frozenset({'Moana'}), confidence=0.42168674698795183, lift=3.262305238459308), OrderedStatistic(items_base=frozenset({'nan', 'Moana', 'Spiderman 3'}), items_add=frozenset({'Intern'}), confidence=0.2892561983471074, lift=3.0391241879827584)]),
#  RelationRecord(items=frozenset({'nan', 'The Revenant', 'Ninja Turtles', 'Intern'}), support=0.007495403761844152, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ninja Turtles', 'The Revenant'}), items_add=frozenset({'nan', 'Intern'}), confidence=0.31360946745562135, lift=3.29499635123135), OrderedStatistic(items_base=frozenset({'nan', 'Ninja Turtles', 'The Revenant'}), items_add=frozenset({'Intern'}), confidence=0.31360946745562135, lift=3.29499635123135)]),
#  RelationRecord(items=frozenset({'Spiderman 3', 'Tomb Rider', 'Intern', 'nan'}), support=0.0060811766369678975, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'nan', 'Spiderman 3'}), confidence=0.2128712871287129, lift=3.237016927499202), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'nan', 'Intern'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2128712871287129, lift=3.237016927499202)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'nan', 'The Revenant', 'Intern'}), support=0.006222599349455522, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'nan', 'The Revenant'}), confidence=0.21782178217821782, lift=3.0200349446709374), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'nan', 'Intern'}), items_add=frozenset({'The Revenant'}), confidence=0.21782178217821782, lift=3.0200349446709374)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'nan', 'World War Z', 'Intern'}), support=0.0067882901994060245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Intern'}), items_add=frozenset({'nan', 'World War Z'}), confidence=0.2376237623762376, lift=3.478752844228522), OrderedStatistic(items_base=frozenset({'World War Z', 'Tomb Rider'}), items_add=frozenset({'nan', 'Intern'}), confidence=0.32432432432432434, lift=3.407573993012329), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'nan', 'Intern'}), items_add=frozenset({'World War Z'}), confidence=0.2376237623762376, lift=3.478752844228522), OrderedStatistic(items_base=frozenset({'nan', 'World War Z', 'Tomb Rider'}), items_add=frozenset({'Intern'}), confidence=0.32432432432432434, lift=3.407573993012329)]),
#  RelationRecord(items=frozenset({'Iron Man', 'Jumanji', 'Tomb Rider', 'nan'}), support=0.00537406307452977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Iron Man', 'Tomb Rider'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.3247863247863248, lift=3.285499431422178), OrderedStatistic(items_base=frozenset({'Iron Man', 'Tomb Rider', 'nan'}), items_add=frozenset({'Jumanji'}), confidence=0.3247863247863248, lift=3.285499431422178)]),
#  RelationRecord(items=frozenset({'nan', 'Jumanji', 'Kung Fu Panda', 'Ninja Turtles'}), support=0.00692971291189365, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kung Fu Panda', 'Ninja Turtles'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.40163934426229514, lift=4.062935340885105), OrderedStatistic(items_base=frozenset({'nan', 'Kung Fu Panda', 'Ninja Turtles'}), items_add=frozenset({'Jumanji'}), confidence=0.40163934426229514, lift=4.062935340885105)]),
#  RelationRecord(items=frozenset({'nan', 'Jumanji', 'Kung Fu Panda', 'Tomb Rider'}), support=0.006222599349455522, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kung Fu Panda', 'Tomb Rider'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.3893805309734513, lift=3.9389266588172736), OrderedStatistic(items_base=frozenset({'nan', 'Kung Fu Panda', 'Tomb Rider'}), items_add=frozenset({'Jumanji'}), confidence=0.3893805309734513, lift=3.9389266588172736)]),
#  RelationRecord(items=frozenset({'Jumanji', 'Ninja Turtles', 'Moana', 'Tomb Rider'}), support=0.004666949512091642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Moana'}), items_add=frozenset({'Ninja Turtles', 'Tomb Rider'}), confidence=0.21019108280254778, lift=3.4404193205944797)]),
#  RelationRecord(items=frozenset({'nan', 'Jumanji', 'Moana', 'Spiderman 3'}), support=0.004949794937066893, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Moana'}), items_add=frozenset({'nan', 'Spiderman 3'}), confidence=0.22292993630573252, lift=3.3899732895007197), OrderedStatistic(items_base=frozenset({'nan', 'Jumanji', 'Moana'}), items_add=frozenset({'Spiderman 3'}), confidence=0.22292993630573252, lift=3.3899732895007197)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'nan', 'Jumanji', 'The Revenant'}), support=0.006364022061943148, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'The Revenant'}), items_add=frozenset({'nan', 'Tomb Rider'}), confidence=0.5487804878048781, lift=3.104341463414634), OrderedStatistic(items_base=frozenset({'nan', 'Jumanji', 'The Revenant'}), items_add=frozenset({'Tomb Rider'}), confidence=0.5487804878048781, lift=3.104341463414634)]),
#  RelationRecord(items=frozenset({'Tomb Rider', 'nan', 'Moana', 'Spiderman 3'}), support=0.0073539810493565266, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Moana', 'Tomb Rider'}), items_add=frozenset({'nan', 'Spiderman 3'}), confidence=0.20233463035019456, lift=3.0767917660348942), OrderedStatistic(items_base=frozenset({'nan', 'Moana', 'Tomb Rider'}), items_add=frozenset({'Spiderman 3'}), confidence=0.20233463035019456, lift=3.0767917660348942)]),
#  RelationRecord(items=frozenset({'Thor', 'Ninja Turtles', 'Spiderman 3', 'nan'}), support=0.005232640362042144, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ninja Turtles', 'Thor'}), items_add=frozenset({'nan', 'Spiderman 3'}), confidence=0.2215568862275449, lift=3.369094069924667), OrderedStatistic(items_base=frozenset({'nan', 'Ninja Turtles', 'Thor'}), items_add=frozenset({'Spiderman 3'}), confidence=0.2215568862275449, lift=3.369094069924667)]),
#  RelationRecord(items=frozenset({'Spotlight', 'Tomb Rider', 'Spiderman 3', 'nan'}), support=0.00537406307452977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Spotlight'}), items_add=frozenset({'nan', 'Spiderman 3'}), confidence=0.20994475138121546, lift=3.192514703261451), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'nan', 'Spotlight'}), items_add=frozenset({'Spiderman 3'}), confidence=0.20994475138121546, lift=3.192514703261451)]),
#  RelationRecord(items=frozenset({'Ninja Turtles', 'Jumanji', 'Tomb Rider', 'Intern', 'nan'}), support=0.004525526799604016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Intern'}), items_add=frozenset({'nan', 'Ninja Turtles', 'Tomb Rider'}), confidence=0.26016260162601623, lift=4.258355916892501), OrderedStatistic(items_base=frozenset({'nan', 'Jumanji', 'Intern'}), items_add=frozenset({'Ninja Turtles', 'Tomb Rider'}), confidence=0.26016260162601623, lift=4.258355916892501), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'Ninja Turtles', 'Intern'}), items_add=frozenset({'nan', 'Jumanji'}), confidence=0.36781609195402293, lift=3.720783385131468), OrderedStatistic(items_base=frozenset({'Tomb Rider', 'nan', 'Ninja Turtles', 'Intern'}), items_add=frozenset({'Jumanji'}), confidence=0.36781609195402293, lift=3.720783385131468)]),
#  RelationRecord(items=frozenset({'Ninja Turtles', 'Moana', 'Tomb Rider', 'Intern', 'nan'}), support=0.004666949512091642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ninja Turtles', 'Moana', 'Tomb Rider'}), items_add=frozenset({'nan', 'Intern'}), confidence=0.2869565217391304, lift=3.0149622068609077), OrderedStatistic(items_base=frozenset({'nan', 'Ninja Turtles', 'Moana', 'Tomb Rider'}), items_add=frozenset({'Intern'}), confidence=0.2869565217391304, lift=3.0149622068609077)]),
#  RelationRecord(items=frozenset({'Ninja Turtles', 'Jumanji', 'Moana', 'Tomb Rider', 'nan'}), support=0.004666949512091642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jumanji', 'Moana'}), items_add=frozenset({'nan', 'Ninja Turtles', 'Tomb Rider'}), confidence=0.21019108280254778, lift=3.4404193205944797), OrderedStatistic(items_base=frozenset({'nan', 'Jumanji', 'Moana'}), items_add=frozenset({'Ninja Turtles', 'Tomb Rider'}), confidence=0.21019108280254778, lift=3.4404193205944797)])]
